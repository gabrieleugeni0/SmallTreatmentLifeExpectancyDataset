# %% [markdown]
# #### **Sobre o dataset:**
#
# [Life Expectancy (WHO)] (https://www.kaggle.com/datasets/kumarajarshi/life-expectancy-who)
#
#     Considerando dados de um período de 2000 a 2015 (16 anos) para todos os países, este dataset visa auxiliar na realização de uma análise preditiva a respeito da expectativa de vida. Imunizações importantes como Hepatite B, Poliomielite e Difteria também serão consideradas. Em poucas palavras, este estudo se concentrará em fatores de imunização, fatores de mortalidade, fatores econômicos, fatores sociais, além de outros fatores relacionados à saúde.
#
#     Como as observações deste conjunto de dados são baseadas em diferentes países, será mais fácil para um país determinar o fator preditivo que está contribuindo para o menor valor da expectativa de vida. Além disso, ajudará a sugerir a um país qual área deve ser dada importância para melhorar de forma eficiente a expectativa de vida de sua população.
#
#     Facilitará o processo de análise de qual ou quais os fatores preditivos que estão contribuindo para diminuir o valor da expectativa de vida e também o de identificação de qual área deve receber mais atenção quanto a formas de aumento da expectativa de vida de sua população.
#
# #### **Descrição das colunas:**
#
# - **Country:** País
# - **Year:** Ano
# - **Status:** Estado Desenvolvido ou Em Desenvolvimento
# - **Life Expectancy:** Expectativa de vida
# - **Adult Mortality:** Taxa de mostalidade em adultos de ambos os sexos (probabilidade de morrer entre 15 e 60 anos por 1000 habitantes)
# - **Infant Deaths:** Número de óbitos infantis por 1000 habitantes
# - **Alcohol:** Consumo registrado por indivíduo acima de 15 anos (em litros)
# - **Percentage Expenditure:** Gastos com saúde como porcentagem do Produto Interno Bruto per capita (%)
# - **Hepatitis B:** Cobertura vacinal contra hepatite B (HepB) em crianças de 1 ano (%)
# - **Measles:** número de casos de Sarampo notificados por 1000 habitantes
# - **BMI:** Índice de Massa Corporal Médio de toda a população
# - **Under-Five Deaths:** Número de mortes de menores de cinco anos por 1000 habitantes
# - **Polio:** Cobertura vacinal contra pólio (Pol3) em crianças de 1 ano (%)
# - **Total expenditure:** Gastos do governo geral com saúde como porcentagem do gasto total do governo (%)
# - **Diphtheria:** Cobertura vacinal contra difteria, tétano e coqueluche (DTP3) em crianças de 1 ano de idade (%)
# - **HIV/AIDS:** Mortes por 1 000 nascidos vivos HIV/AIDS (0-4 anos)
# - **GDP:** Produto Interno Bruto per capita (em USD)
# - **Population:** População do país
# - **Tthinness 1-19 years:** Prevalência de magreza em crianças e adolescentes de 10 a 19 anos (%)
# - **Thinness 5-9 years:**  Prevalência de magreza em crianças de 5 a 9 anos (%)
# - **Income composition of resources:** Índice de Desenvolvimento Humano em termos de composição de renda dos recursos (índice variando de 0 a 1)
# - **Schooling:** Número de anos de escolaridade (anos)

# %%
# Importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

# Constantes
datasource = './Life Expectancy Data.csv'

# %%
# Leitura da base de dados
df_life_expectancy = pd.read_csv(datasource)

# Visualização do dataframe
df_life_expectancy.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing            65.000          263.000
# 1  Afghanistan  2014  Developing            59.900          271.000
# 2  Afghanistan  2013  Developing            59.900          268.000
# 3  Afghanistan  2012  Developing            59.500          272.000
# 4  Afghanistan  2011  Developing            59.200          275.000
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62    0.010                  71.280       65.000      1154  ...
# 1             64    0.010                  73.524       62.000       492  ...
# 2             66    0.010                  73.219       64.000       430  ...
# 3             69    0.010                  78.184       67.000      2787  ...
# 4             71    0.010                   7.097       68.000      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS     GDP   Population  \
# ...

# %%
# Renomeando cabeçalho das colunas para pt-BR e padronizando nomenclaturas
df_life_expectancy = df_life_expectancy.rename(columns= {'Country' : 'País', 'Year' : 'Ano',\
    'Life expectancy ' : 'Expectativa de vida', 'Adult Mortality' : 'Mortalidade de adultos',\
    'infant deaths' : 'Mortalidade de crianças', 'Alcohol' : 'Consumo de álcool', \
    'percentage expenditure' : 'Gastos com saúde (valor percentual)', 'Hepatitis B' : 'Cobertura vacinal Hepatite B',\
    'Measles ' : 'Casos de Sarampo', ' BMI ' : 'IMC', 'under-five deaths ' : 'Mortes menores de 5 anos',\
    'Polio' : 'Cobertura vacinal Polio', 'Total expenditure' : 'Gastos com saúde', \
    'Diphtheria ' : 'Cobertura vacinal Difteria',' HIV/AIDS' : 'Mortes por HIV/AIDS', 'GDP' : 'PIB',\
    'Population' : 'População', ' thinness  1-19 years' : 'Magreza (10 a 19 anos)',\
    ' thinness 5-9 years' : 'Magreza (5 a 9 anos)', 'Income composition of resources' : 'IDH', \
    'Schooling' : 'Anos de escolaridade'})
df_life_expectancy.head(10)
# Out:
#           País   Ano      Status  Expectativa de vida  Mortalidade de adultos  \
# 0  Afghanistan  2015  Developing               65.000                 263.000
# 1  Afghanistan  2014  Developing               59.900                 271.000
# 2  Afghanistan  2013  Developing               59.900                 268.000
# 3  Afghanistan  2012  Developing               59.500                 272.000
# 4  Afghanistan  2011  Developing               59.200                 275.000
# 5  Afghanistan  2010  Developing               58.800                 279.000
# 6  Afghanistan  2009  Developing               58.600                 281.000
# 7  Afghanistan  2008  Developing               58.100                 287.000
# 8  Afghanistan  2007  Developing               57.500                 295.000
# 9  Afghanistan  2006  Developing               57.300                 295.000
#
#    Mortalidade de crianças  Consumo de álcool  \
# 0                       62              0.010
# ...

# %%
# Informações sobre o dataframe
df_life_expectancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   País                                 2938 non-null   object
#  1   Ano                                  2938 non-null   int64
#  2   Status                               2938 non-null   object
#  3   Expectativa de vida                  2928 non-null   float64
#  4   Mortalidade de adultos               2928 non-null   float64
#  5   Mortalidade de crianças              2938 non-null   int64
#  6   Consumo de álcool                    2744 non-null   float64
#  7   Gastos com saúde (valor percentual)  2938 non-null   float64
#  8   Cobertura vacinal Hepatite B         2385 non-null   float64
#  9   Casos de Sarampo                     2938 non-null   int64
#  10  IMC                                  2904 non-null   float64
# ...

# %%
# Análise de dados nulos de forma tabular
df_life_expectancy.isna().sum()
# Out:
# País                                     0
# Ano                                      0
# Status                                   0
# Expectativa de vida                     10
# Mortalidade de adultos                  10
# Mortalidade de crianças                  0
# Consumo de álcool                      194
# Gastos com saúde (valor percentual)      0
# Cobertura vacinal Hepatite B           553
# Casos de Sarampo                         0
# IMC                                     34
# Mortes menores de 5 anos                 0
# Cobertura vacinal Polio                 19
# Gastos com saúde                       226
# Cobertura vacinal Difteria              19
# Mortes por HIV/AIDS                      0
# PIB                                    448
# População                              652
# Magreza (10 a 19 anos)                  34
# Magreza (5 a 9 anos)                    34
# IDH                                    167
# Anos de escolaridade                   163
# ...

# %%
# Análise de dados nulos com mapa de calor do seaborn.heatmap()
plt.figure(figsize=(5,5))
sns.heatmap(df_life_expectancy.isna().transpose(), vmin=0, vmax=1, cmap='coolwarm')
plt.title('Mapa de Calor dos Dados Nulos', size=15)
plt.show()

# %%
# Verificando as variações estatísticas dos dados
pd.set_option('float_format','{:.3f}'.format)
df_life_expectancy.describe().transpose()
# Out:
#                                        count         mean          std  \
# Ano                                 2938.000     2007.519        4.614
# Expectativa de vida                 2928.000       69.225        9.524
# Mortalidade de adultos              2928.000      164.796      124.292
# Mortalidade de crianças             2938.000       30.304      117.927
# Consumo de álcool                   2744.000        4.603        4.052
# Gastos com saúde (valor percentual) 2938.000      738.251     1987.915
# Cobertura vacinal Hepatite B        2385.000       80.940       25.070
# Casos de Sarampo                    2938.000     2419.592    11467.272
# IMC                                 2904.000       38.321       20.044
# Mortes menores de 5 anos            2938.000       42.036      160.446
# Cobertura vacinal Polio             2919.000       82.550       23.428
# Gastos com saúde                    2712.000        5.938        2.498
# ...

# %% [markdown]
# **Análises realizadas pelas estatísticas descritivas apresentadas acima:**
# - Verificação do período de anos dos dados, referente aos anos de 2000-2015;
# - Verificação da coluna Income composition of resources	com valores apenas entre 0 e 1;
# - Verificação das colunas com dados de imunização vacinal com valores entre 0 e 100%;

# %% [markdown]
# **Inferências:**
# - Nota-se que não existem colunas com dados "congelados"
# - Também não foram observadas colunas com baixíssima variância
# - Existe grande variabilidade em alguns dados, sendo possível presumir que a mesma é gerada pela diferença entre os países

# %%
# Analizando a variabilidade dos dados de IDH a partir de um histograma
var = 'IDH'
plt.figure(figsize=(5,5))
plt.hist(df_life_expectancy[var], alpha=0.5)
plt.xlabel('IDH')
plt.show()

# %%
# Analizando a variabilidade dos dados de Gastos com saúde com gráfico do pandas
var = 'Gastos com saúde'
df_life_expectancy[var].plot(lw=0.5)
# Out:
# <AxesSubplot: >

# %%
# Verificando se existem duplicidade de linhas
print(f'Quantidade de linhas duplicadas: {df_life_expectancy.duplicated().sum()}')
# Out:
# Quantidade de linhas duplicadas: 0

# %%
# Verificando se existem duplicidade nos dados das colunas
comb = itertools.combinations(df_life_expectancy.columns, 2)

dup_cols = []
for col1, col2 in comb:
    if (col1 not in dup_cols) and (col2 not in dup_cols):
        if df_life_expectancy[col1].equals(df_life_expectancy[col2]):
            dup_cols.append(col1)

print(f'Quantidade de colunas duplicadas: {len(dup_cols)}')
# Out:
# Quantidade de colunas duplicadas: 0

# %%
# Verificando se possui duplicidade nos dados de país e ano
df_life_expectancy.duplicated(["País", "Ano"]).sum()
# Out:
# 0

# %%
# Verificando se possui registros de todos os países
df_life_expectancy['País'].nunique()
# Out:
# 193

# %% [markdown]
# **Constataram-se registros de 193 países**

# %%
# Verificando se possui registros de todos os anos para todos os países
df_life_expectancy_filter = df_life_expectancy[['País', 'Ano']].groupby('País').nunique('Ano')
mask_filter = df_life_expectancy_filter['Ano'] != 16
df_life_expectancy_filter[mask_filter]
# Out:
#                        Ano
# País
# Cook Islands             1
# Dominica                 1
# Marshall Islands         1
# Monaco                   1
# Nauru                    1
# Niue                     1
# Palau                    1
# Saint Kitts and Nevis    1
# San Marino               1
# Tuvalu                   1

# %% [markdown]
# **Constatou-se que 10 países não possuem os registros dos 16 anos (2000 - 2015)**

# %% [markdown]
# **________________________________________________________________________________________________________________________________________________________________________________________**

# %% [markdown]
# **Otimizando o tamanho do dataframe**

# %%
# %%capture
# Otimizando o tamanho do dataframe mudando os tipos dos dados

df_life_expectancy_otimized = df_life_expectancy
df_life_expectancy_otimized = df_life_expectancy_otimized.dropna()

df_life_expectancy_otimized[['Expectativa de vida','Ano','Cobertura vacinal Hepatite B'\
    ,'IMC','Cobertura vacinal Polio','Cobertura vacinal Difteria']] = df_life_expectancy_otimized\
    [['Expectativa de vida','Ano','Cobertura vacinal Hepatite B','IMC','Cobertura vacinal Polio',\
    'Cobertura vacinal Difteria']].astype('int16')
df_life_expectancy_otimized[['Casos de Sarampo','Mortes menores de 5 anos']] = df_life_expectancy_otimized\
    [['Casos de Sarampo','Mortes menores de 5 anos']].astype('int32')
df_life_expectancy_otimized[['Mortalidade de adultos','Mortalidade de crianças','População']]\
    = df_life_expectancy_otimized[['Mortalidade de adultos','Mortalidade de crianças','População']].astype('int64')
df_life_expectancy_otimized[['Consumo de álcool','Gastos com saúde (valor percentual)','IMC','Gastos com saúde',\
    'Mortes por HIV/AIDS','Magreza (10 a 19 anos)','Magreza (5 a 9 anos)','IDH','Anos de escolaridade']]\
     = df_life_expectancy_otimized[['Consumo de álcool','Gastos com saúde (valor percentual)','IMC',\
    'Gastos com saúde','Mortes por HIV/AIDS','Magreza (10 a 19 anos)','Magreza (5 a 9 anos)','IDH',\
    'Anos de escolaridade']].astype('float32')

# %%
#Usando .info() para comparar o tamanho do novo dataframe otimizado
df_life_expectancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   País                                 2938 non-null   object
#  1   Ano                                  2938 non-null   int64
#  2   Status                               2938 non-null   object
#  3   Expectativa de vida                  2928 non-null   float64
#  4   Mortalidade de adultos               2928 non-null   float64
#  5   Mortalidade de crianças              2938 non-null   int64
#  6   Consumo de álcool                    2744 non-null   float64
#  7   Gastos com saúde (valor percentual)  2938 non-null   float64
#  8   Cobertura vacinal Hepatite B         2385 non-null   float64
#  9   Casos de Sarampo                     2938 non-null   int64
#  10  IMC                                  2904 non-null   float64
# ...

# %%
df_life_expectancy_otimized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1649 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   País                                 1649 non-null   object
#  1   Ano                                  1649 non-null   int16
#  2   Status                               1649 non-null   object
#  3   Expectativa de vida                  1649 non-null   int16
#  4   Mortalidade de adultos               1649 non-null   int64
#  5   Mortalidade de crianças              1649 non-null   int64
#  6   Consumo de álcool                    1649 non-null   float32
#  7   Gastos com saúde (valor percentual)  1649 non-null   float32
#  8   Cobertura vacinal Hepatite B         1649 non-null   int16
#  9   Casos de Sarampo                     1649 non-null   int32
#  10  IMC                                  1649 non-null   float32
# ...
